# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('dynverse_datasets_metadata.xlsx')
df.head()
# Out:
#          pmid       date    technology    accession standard  \
# 0  26430063.0 2015-10-01     smart-seq     GSE59114     gold
# 1  26430063.0 2015-10-01     smart-seq     GSE59114     gold
# 2  25599176.0 2014-12-29   fluidigm c1  E-MTAB-2805     gold
# 3  26054720.0 2015-07-16   fluidigm c1     GSE60781     gold
# 4  26046443.0 2015-06-03  Tang et. al.     GSE63818     gold
#
#       standard_determination  dynamic_process   material organism processing  \
# 0                       FACS            aging  polyA RNA    mouse    Minimal
# 1                       FACS            aging  polyA RNA    mouse    Minimal
# 2                       FACS       cell_cycle  polyA RNA    mouse    Minimal
# 3                       FACS  differentiation  polyA RNA    mouse    Minimal
# 4  timeseries, sample origin  differentiation  polyA RNA    human    Minimal
#
#   notes                                              id trajectory_type  \
# ...

# %%
def download_dynverse_dataset(data_uri: str):
    ...
